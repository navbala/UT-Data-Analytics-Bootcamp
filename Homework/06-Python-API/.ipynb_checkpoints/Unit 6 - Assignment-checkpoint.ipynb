# %% [markdown]
# # WeatherPy
# ## Analysis
#  - The closer a city is to the equator, the higher the temperature (F) of that city. This is noted in the "City Latitude vs. Temperature (3/1/2018)" graph, below, where the highest data points for temperature are above the "0" latitude (note that the equator is at latitude 0).
#  - The Northern Hemisphere typically has higher wind speeds (mph). This is indicated in the "City Latitude vs. Wind Speed (3/1/2018)" graph where the data points for wind speed for cities in the Nothern Hemisphere (latitudes 0 to 90) are higher than for cities in the Southern Hemisphere (latitude -90 to 0).
#  - The Southern Hemisphere typically has higher humidity %). This is indicated in the "City Latitude vs. Humidity (3/1/2018)" graph where there is greater number of data points with higher humidty for cities in the Souther Hemisphere (latitudes -90 to 0) than for cities in the Northern Hemisphere (latitude 0 to 90).

# %%
# Import Dependencies
import requests as req
import json
from citipy import citipy
from random import uniform
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# API config and URL info
api_key = "84fe59f3ffa1bf7920c39149bf3dde70"
url = "http://api.openweathermap.org/data/2.5/weather?"

# %%
## Generate random lng/lat to put into citipy (citipy take in 2 coordinates (lng, lat))

# Functions for generating random latitude
def rand_lat():
  return uniform(-90, 90)

# Function for generating random longitude
def rand_lng():
  return uniform(-180,180)

# %%
# Create empty df to hold weather data for each city 
weather_data_df = pd.DataFrame(columns=["City", "Cloudiness", "Country", "Date", "Humidity", "Lat", "Lng", "Temperature", "Wind Speed"])

# Create initial variables for looping
counter = 0
unique_cities = []

# Initial print header for output log
print("Beginning Data Retrieval")
print("---------------------------")

# While loop to only capture cities without null weather data
while counter < 500:
    # Retrieve a city for each random lat/lng generated
    # Obtain the JSON response for each city
    city = citipy.nearest_city(rand_lat(), rand_lng())
    query_url =  url + "appid=" + api_key + "&q=" + city.city_name + "," + city.country_code + "&units=imperial"
    weather_response = req.get(query_url)
    weather_json = weather_response.json()
    
    # If statement for only cities with weather data (internal paramer "cod" = 200)
    if weather_json["cod"] == 200:
        # Check for duplicates
        if weather_json["name"] not in unique_cities:
            # Append weather data for the city to df
            weather_data_df = weather_data_df.append([{"City": weather_json["name"],
                                                       "Temperature": weather_json["main"]["temp"],
                                                       "Humidity": weather_json["main"]["humidity"],
                                                       "Cloudiness": weather_json["clouds"]["all"],
                                                       "Wind Speed": weather_json["wind"]["speed"],
                                                       "Lat": weather_json["coord"]["lat"],
                                                       "Country": weather_json["sys"]["country"],
                                                       "Lng": weather_json["coord"]["lon"],
                                                       "Date": weather_json["dt"]
                                                      }])
            
            # Add to city-weather data confirmed counter         
            counter += 1
            
            # Append the city to the unique cities list
            unique_cities.append(weather_json["name"])
        
            # Print log statements
            print("Processing Record #" + str(counter) + " | City ID: " + str(weather_json["id"]) + " | City Name: " + city.city_name)
            print(query_url)
# Out:
# Beginning Data Retrieval
# ---------------------------
# Processing Record #1 | City ID: 2744042 | City Name: zandvoort
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=zandvoort,nl&units=imperial
# Processing Record #2 | City ID: 3573061 | City Name: saint george
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=saint george,bm&units=imperial
# Processing Record #3 | City ID: 2729907 | City Name: longyearbyen
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=longyearbyen,sj&units=imperial
# Processing Record #4 | City ID: 2191562 | City Name: dunedin
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=dunedin,nz&units=imperial
# Processing Record #5 | City ID: 2015306 | City Name: tiksi
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=tiksi,ru&units=imperial
# Processing Record #6 | City ID: 2077963 | City Name: albany
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=albany,au&units=imperial
# Processing Record #7 | City ID: 5118226 | City Name: garden city
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=garden city,us&units=imperial
# Processing Record #8 | City ID: 3370903 | City Name: jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=jamestown,sh&units=imperial
# Processing Record #9 | City ID: 2389853 | City Name: bimbo
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=bimbo,cf&units=imperial
# Processing Record #10 | City ID: 3833367 | City Name: ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=ushuaia,ar&units=imperial
# Processing Record #11 | City ID: 1006984 | City Name: east london
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=east london,za&units=imperial
# Processing Record #12 | City ID: 778707 | City Name: mehamn
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=mehamn,no&units=imperial
# Processing Record #13 | City ID: 3671519 | City Name: puerto carreno
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=puerto carreno,co&units=imperial
# Processing Record #14 | City ID: 2206939 | City Name: bluff
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=bluff,nz&units=imperial
# Processing Record #15 | City ID: 4030556 | City Name: rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=rikitea,pf&units=imperial
# Processing Record #16 | City ID: 1490036 | City Name: tashtyp
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=tashtyp,ru&units=imperial
# Processing Record #17 | City ID: 2293549 | City Name: abengourou
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=abengourou,ci&units=imperial
# Processing Record #18 | City ID: 3652764 | City Name: puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=puerto ayora,ec&units=imperial
# Processing Record #19 | City ID: 1490256 | City Name: talnakh
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=talnakh,ru&units=imperial
# Processing Record #20 | City ID: 1788852 | City Name: xining
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=xining,cn&units=imperial
# Processing Record #21 | City ID: 3576994 | City Name: cockburn town
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=cockburn town,tc&units=imperial
# Processing Record #22 | City ID: 5848280 | City Name: kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=kapaa,us&units=imperial
# Processing Record #23 | City ID: 2068110 | City Name: kununurra
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=kununurra,au&units=imperial
# Processing Record #24 | City ID: 4020109 | City Name: atuona
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=atuona,pf&units=imperial
# Processing Record #25 | City ID: 3471451 | City Name: arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=arraial do cabo,br&units=imperial
# Processing Record #26 | City ID: 3397967 | City Name: itaituba
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=itaituba,br&units=imperial
# Processing Record #27 | City ID: 3430443 | City Name: necochea
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=necochea,ar&units=imperial
# Processing Record #28 | City ID: 3863379 | City Name: mar del plata
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=mar del plata,ar&units=imperial
# Processing Record #29 | City ID: 3521342 | City Name: playa del carmen
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=playa del carmen,mx&units=imperial
# Processing Record #30 | City ID: 5855927 | City Name: hilo
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=hilo,us&units=imperial
# Processing Record #31 | City ID: 1507390 | City Name: dikson
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=dikson,ru&units=imperial
# Processing Record #32 | City ID: 3418910 | City Name: upernavik
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=upernavik,gl&units=imperial
# Processing Record #33 | City ID: 708313 | City Name: zatoka
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=zatoka,ua&units=imperial
# Processing Record #34 | City ID: 2022572 | City Name: khatanga
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=khatanga,ru&units=imperial
# Processing Record #35 | City ID: 4407665 | City Name: kodiak
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=kodiak,us&units=imperial
# Processing Record #36 | City ID: 2392308 | City Name: ouidah
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=ouidah,bj&units=imperial
# Processing Record #37 | City ID: 4032243 | City Name: vaini
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=vaini,to&units=imperial
# Processing Record #38 | City ID: 2013375 | City Name: vitim
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=vitim,ru&units=imperial
# Processing Record #39 | City ID: 5895424 | City Name: victoria
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=victoria,ca&units=imperial
# Processing Record #40 | City ID: 487928 | City Name: novikovo
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=novikovo,ru&units=imperial
# Processing Record #41 | City ID: 2063042 | City Name: port hedland
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=port hedland,au&units=imperial
# Processing Record #42 | City ID: 5947754 | City Name: elk point
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=elk point,ca&units=imperial
# Processing Record #43 | City ID: 2400547 | City Name: gamba
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=gamba,ga&units=imperial
# Processing Record #44 | City ID: 3533462 | City Name: tres palos
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=tres palos,mx&units=imperial
# Processing Record #45 | City ID: 3874787 | City Name: punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=punta arenas,cl&units=imperial
# Processing Record #46 | City ID: 6185377 | City Name: yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=yellowknife,ca&units=imperial
# Processing Record #47 | City ID: 2075265 | City Name: busselton
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=busselton,au&units=imperial
# Processing Record #48 | City ID: 3421719 | City Name: narsaq
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=narsaq,gl&units=imperial
# Processing Record #49 | City ID: 3896218 | City Name: castro
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=castro,cl&units=imperial
# Processing Record #50 | City ID: 2163355 | City Name: hobart
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=hobart,au&units=imperial
# Processing Record #51 | City ID: 1640044 | City Name: kijang
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=kijang,id&units=imperial
# Processing Record #52 | City ID: 2094746 | City Name: kandrian
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=kandrian,pg&units=imperial
# Processing Record #53 | City ID: 587378 | City Name: agdas
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=agdas,az&units=imperial
# Processing Record #54 | City ID: 3461370 | City Name: imbituba
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=imbituba,br&units=imperial
# Processing Record #55 | City ID: 949703 | City Name: thaba nchu
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=thaba nchu,za&units=imperial
# Processing Record #56 | City ID: 3893629 | City Name: coquimbo
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=coquimbo,cl&units=imperial
# Processing Record #57 | City ID: 1735450 | City Name: lumut
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=lumut,my&units=imperial
# Processing Record #58 | City ID: 866062 | City Name: iskateley
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=iskateley,ru&units=imperial
# Processing Record #59 | City ID: 2065176 | City Name: murray bridge
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=murray bridge,au&units=imperial
# Processing Record #60 | City ID: 2110227 | City Name: butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=butaritari,ki&units=imperial
# Processing Record #61 | City ID: 3401225 | City Name: amapa
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=amapa,br&units=imperial
# Processing Record #62 | City ID: 964420 | City Name: port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=port elizabeth,za&units=imperial
# Processing Record #63 | City ID: 3361934 | City Name: saldanha
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=saldanha,za&units=imperial
# Processing Record #64 | City ID: 6165406 | City Name: thompson
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=thompson,ca&units=imperial
# Processing Record #65 | City ID: 2636790 | City Name: stornoway
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=stornoway,gb&units=imperial
# Processing Record #66 | City ID: 2112802 | City Name: hasaki
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=hasaki,jp&units=imperial
# Processing Record #67 | City ID: 1024552 | City Name: xai-xai
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=xai-xai,mz&units=imperial
# Processing Record #68 | City ID: 3424607 | City Name: tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=tasiilaq,gl&units=imperial
# Processing Record #69 | City ID: 935215 | City Name: saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=saint-philippe,re&units=imperial
# Processing Record #70 | City ID: 2126123 | City Name: chokurdakh
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=chokurdakh,ru&units=imperial
# Processing Record #71 | City ID: 1106677 | City Name: bambous virieux
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=bambous virieux,mu&units=imperial
# Processing Record #72 | City ID: 3404558 | City Name: cabedelo
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=cabedelo,br&units=imperial
# Processing Record #73 | City ID: 2128975 | City Name: nemuro
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=nemuro,jp&units=imperial
# Processing Record #74 | City ID: 6533368 | City Name: moranbah
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=moranbah,au&units=imperial
# Processing Record #75 | City ID: 3366880 | City Name: hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=hermanus,za&units=imperial
# Processing Record #76 | City ID: 2137773 | City Name: vao
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=vao,nc&units=imperial
# Processing Record #77 | City ID: 2018735 | City Name: nyurba
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=nyurba,ru&units=imperial
# Processing Record #78 | City ID: 2267254 | City Name: lagoa
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=lagoa,pt&units=imperial
# Processing Record #79 | City ID: 2094342 | City Name: kavieng
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=kavieng,pg&units=imperial
# Processing Record #80 | City ID: 2121025 | City Name: srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=srednekolymsk,ru&units=imperial
# Processing Record #81 | City ID: 924055 | City Name: salima
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=salima,mw&units=imperial
# Processing Record #82 | City ID: 2155415 | City Name: new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=new norfolk,au&units=imperial
# Processing Record #83 | City ID: 4031574 | City Name: provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=provideniya,ru&units=imperial
# Processing Record #84 | City ID: 286621 | City Name: salalah
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=salalah,om&units=imperial
# Processing Record #85 | City ID: 3466165 | City Name: cidreira
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=cidreira,br&units=imperial
# Processing Record #86 | City ID: 964432 | City Name: port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=port alfred,za&units=imperial
# Processing Record #87 | City ID: 6170031 | City Name: tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=tuktoyaktuk,ca&units=imperial
# Processing Record #88 | City ID: 1735902 | City Name: sibu
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=sibu,my&units=imperial
# Processing Record #89 | City ID: 6089245 | City Name: norman wells
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=norman wells,ca&units=imperial
# Processing Record #90 | City ID: 3369157 | City Name: cape town
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=cape town,za&units=imperial
# Processing Record #91 | City ID: 4031742 | City Name: egvekinot
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=egvekinot,ru&units=imperial
# Processing Record #92 | City ID: 2428228 | City Name: massakory
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=massakory,td&units=imperial
# Processing Record #93 | City ID: 3883457 | City Name: lebu
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=lebu,cl&units=imperial
# Processing Record #94 | City ID: 4021858 | City Name: guerrero negro
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=guerrero negro,mx&units=imperial
# Processing Record #95 | City ID: 2177069 | City Name: ballina
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=ballina,au&units=imperial
# Processing Record #96 | City ID: 1283285 | City Name: jumla
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=jumla,np&units=imperial
# Processing Record #97 | City ID: 934322 | City Name: mahebourg
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=mahebourg,mu&units=imperial
# Processing Record #98 | City ID: 2206894 | City Name: hokitika
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=hokitika,nz&units=imperial
# Processing Record #99 | City ID: 5882953 | City Name: aklavik
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=aklavik,ca&units=imperial
# Processing Record #100 | City ID: 1855540 | City Name: naze
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=naze,jp&units=imperial
# Processing Record #101 | City ID: 498856 | City Name: sandovo
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=sandovo,ru&units=imperial
# Processing Record #102 | City ID: 1282256 | City Name: hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=hithadhoo,mv&units=imperial
# Processing Record #103 | City ID: 2180815 | City Name: tuatapere
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=tuatapere,nz&units=imperial
# Processing Record #104 | City ID: 4252975 | City Name: barrow
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=barrow,us&units=imperial
# Processing Record #105 | City ID: 5924351 | City Name: clyde river
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=clyde river,ca&units=imperial
# Processing Record #106 | City ID: 1054329 | City Name: vangaindrano
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=vangaindrano,mg&units=imperial
# Processing Record #107 | City ID: 3355672 | City Name: luderitz
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=luderitz,na&units=imperial
# Processing Record #108 | City ID: 2315728 | City Name: gemena
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=gemena,cd&units=imperial
# Processing Record #109 | City ID: 650225 | City Name: kuopio
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=kuopio,fi&units=imperial
# Processing Record #110 | City ID: 3419842 | City Name: sisimiut
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=sisimiut,gl&units=imperial
# Processing Record #111 | City ID: 512861 | City Name: panino
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=panino,ru&units=imperial
# Processing Record #112 | City ID: 3663517 | City Name: livramento
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=livramento,br&units=imperial
# Processing Record #113 | City ID: 2219235 | City Name: awbari
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=awbari,ly&units=imperial
# Processing Record #114 | City ID: 1015776 | City Name: bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=bredasdorp,za&units=imperial
# Processing Record #115 | City ID: 2450173 | City Name: taoudenni
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=taoudenni,ml&units=imperial
# Processing Record #116 | City ID: 3388869 | City Name: jutai
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=jutai,br&units=imperial
# Processing Record #117 | City ID: 2181625 | City Name: te anau
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=te anau,nz&units=imperial
# Processing Record #118 | City ID: 2374583 | City Name: bubaque
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=bubaque,gw&units=imperial
# Processing Record #119 | City ID: 2147914 | City Name: sunbury
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=sunbury,au&units=imperial
# Processing Record #120 | City ID: 6690296 | City Name: saint-joseph
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=saint-joseph,re&units=imperial
# Processing Record #121 | City ID: 3661756 | City Name: uarini
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=uarini,br&units=imperial
# Processing Record #122 | City ID: 5204278 | City Name: oil city
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=oil city,us&units=imperial
# Processing Record #123 | City ID: 2121385 | City Name: severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=severo-kurilsk,ru&units=imperial
# Processing Record #124 | City ID: 6171633 | City Name: ucluelet
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=ucluelet,ca&units=imperial
# Processing Record #125 | City ID: 6167817 | City Name: torbay
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=torbay,ca&units=imperial
# Processing Record #126 | City ID: 1489401 | City Name: toora-khem
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=toora-khem,ru&units=imperial
# Processing Record #127 | City ID: 1503527 | City Name: khovu-aksy
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=khovu-aksy,ru&units=imperial
# Processing Record #128 | City ID: 5880568 | City Name: bethel
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=bethel,us&units=imperial
# Processing Record #129 | City ID: 4035715 | City Name: avarua
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=avarua,ck&units=imperial
# Processing Record #130 | City ID: 2411397 | City Name: georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=georgetown,sh&units=imperial
# Processing Record #131 | City ID: 3645532 | City Name: ciudad bolivar
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=ciudad bolivar,ve&units=imperial
# Processing Record #132 | City ID: 2092164 | City Name: lorengau
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=lorengau,pg&units=imperial
# Processing Record #133 | City ID: 1263751 | City Name: mangrol
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=mangrol,in&units=imperial
# Processing Record #134 | City ID: 2316259 | City Name: bulungu
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=bulungu,cd&units=imperial
# Processing Record #135 | City ID: 826996 | City Name: udarnyy
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=udarnyy,ru&units=imperial
# Processing Record #136 | City ID: 202065 | City Name: kibuye
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=kibuye,rw&units=imperial
# Processing Record #137 | City ID: 5983720 | City Name: iqaluit
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=iqaluit,ca&units=imperial
# Processing Record #138 | City ID: 546105 | City Name: nikolskoye
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=nikolskoye,ru&units=imperial
# Processing Record #139 | City ID: 1633419 | City Name: padang
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=padang,id&units=imperial
# Processing Record #140 | City ID: 3495137 | City Name: pedernales
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=pedernales,do&units=imperial
# Processing Record #141 | City ID: 3831208 | City Name: qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=qaanaaq,gl&units=imperial
# Processing Record #142 | City ID: 3422683 | City Name: kangaatsiaq
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=kangaatsiaq,gl&units=imperial
# Processing Record #143 | City ID: 5849996 | City Name: lahaina
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=lahaina,us&units=imperial
# Processing Record #144 | City ID: 5847411 | City Name: kahului
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=kahului,us&units=imperial
# Processing Record #145 | City ID: 1275960 | City Name: bhilwara
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=bhilwara,in&units=imperial
# Processing Record #146 | City ID: 3374210 | City Name: sao filipe
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=sao filipe,cv&units=imperial
# Processing Record #147 | City ID: 1512019 | City Name: aksarka
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=aksarka,ru&units=imperial
# Processing Record #148 | City ID: 3899695 | City Name: ancud
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=ancud,cl&units=imperial
# Processing Record #149 | City ID: 1168700 | City Name: ormara
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=ormara,pk&units=imperial
# Processing Record #150 | City ID: 2304548 | City Name: anloga
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=anloga,gh&units=imperial
# Processing Record #151 | City ID: 4581833 | City Name: hilton head island
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=hilton head island,us&units=imperial
# Processing Record #152 | City ID: 1641899 | City Name: labuhan
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=labuhan,id&units=imperial
# Processing Record #153 | City ID: 1865309 | City Name: katsuura
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=katsuura,jp&units=imperial
# Processing Record #154 | City ID: 3491161 | City Name: bull savanna
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=bull savanna,jm&units=imperial
# Processing Record #155 | City ID: 2160517 | City Name: launceston
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=launceston,au&units=imperial
# Processing Record #156 | City ID: 3573374 | City Name: the valley
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=the valley,ai&units=imperial
# Processing Record #157 | City ID: 3665202 | City Name: aripuana
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=aripuana,br&units=imperial
# Processing Record #158 | City ID: 1259385 | City Name: port blair
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=port blair,in&units=imperial
# Processing Record #159 | City ID: 2318123 | City Name: yenagoa
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=yenagoa,ng&units=imperial
# Processing Record #160 | City ID: 6255012 | City Name: flinders
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=flinders,au&units=imperial
# Processing Record #161 | City ID: 6087892 | City Name: niagara falls
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=niagara falls,us&units=imperial
# Processing Record #162 | City ID: 2418596 | City Name: koundara
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=koundara,gn&units=imperial
# Processing Record #163 | City ID: 4276248 | City Name: newton
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=newton,us&units=imperial
# Processing Record #164 | City ID: 3407882 | City Name: altamira
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=altamira,br&units=imperial
# Processing Record #165 | City ID: 4004293 | City Name: ixtapa
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=ixtapa,mx&units=imperial
# Processing Record #166 | City ID: 3443061 | City Name: chuy
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=chuy,uy&units=imperial
# Processing Record #167 | City ID: 2077895 | City Name: alice springs
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=alice springs,au&units=imperial
# Processing Record #168 | City ID: 1259688 | City Name: pilibanga
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=pilibanga,in&units=imperial
# Processing Record #169 | City ID: 3577430 | City Name: road town
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=road town,vg&units=imperial
# Processing Record #170 | City ID: 3416888 | City Name: grindavik
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=grindavik,is&units=imperial
# Processing Record #171 | City ID: 3671450 | City Name: inirida
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=inirida,co&units=imperial
# Processing Record #172 | City ID: 556268 | City Name: ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=ostrovnoy,ru&units=imperial
# Processing Record #173 | City ID: 1651531 | City Name: ambon
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=ambon,id&units=imperial
# Processing Record #174 | City ID: 2015701 | City Name: taksimo
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=taksimo,ru&units=imperial
# Processing Record #175 | City ID: 4036284 | City Name: alofi
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=alofi,nu&units=imperial
# Processing Record #176 | City ID: 3381041 | City Name: mana
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=mana,gf&units=imperial
# Processing Record #177 | City ID: 5850554 | City Name: makakilo city
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=makakilo city,us&units=imperial
# Processing Record #178 | City ID: 2127202 | City Name: anadyr
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=anadyr,ru&units=imperial
# Processing Record #179 | City ID: 1650527 | City Name: balikpapan
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=balikpapan,id&units=imperial
# Processing Record #180 | City ID: 1574023 | City Name: thanh hoa
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=thanh hoa,vn&units=imperial
# Processing Record #181 | City ID: 3832899 | City Name: viedma
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=viedma,ar&units=imperial
# Processing Record #182 | City ID: 2208248 | City Name: kaitangata
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=kaitangata,nz&units=imperial
# Processing Record #183 | City ID: 4929376 | City Name: athol
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=athol,us&units=imperial
# Processing Record #184 | City ID: 5972291 | City Name: havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=havre-saint-pierre,ca&units=imperial
# Processing Record #185 | City ID: 2176639 | City Name: batemans bay
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=batemans bay,au&units=imperial
# Processing Record #186 | City ID: 921028 | City Name: chadiza
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=chadiza,zm&units=imperial
# Processing Record #187 | City ID: 2068655 | City Name: katherine
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=katherine,au&units=imperial
# Processing Record #188 | City ID: 2015913 | City Name: suntar
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=suntar,ru&units=imperial
# Processing Record #189 | City ID: 2084442 | City Name: vanimo
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=vanimo,pg&units=imperial
# Processing Record #190 | City ID: 6174254 | City Name: viking
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=viking,ca&units=imperial
# Processing Record #191 | City ID: 3382160 | City Name: cayenne
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=cayenne,gf&units=imperial
# Processing Record #192 | City ID: 554830 | City Name: izhma
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=izhma,ru&units=imperial
# Processing Record #193 | City ID: 2300379 | City Name: ho
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=ho,gh&units=imperial
# Processing Record #194 | City ID: 2185329 | City Name: waipawa
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=waipawa,nz&units=imperial
# Processing Record #195 | City ID: 5314245 | City Name: show low
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=show low,us&units=imperial
# Processing Record #196 | City ID: 1835848 | City Name: seoul
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=seoul,kr&units=imperial
# Processing Record #197 | City ID: 5720495 | City Name: coos bay
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=coos bay,us&units=imperial
# Processing Record #198 | City ID: 2501152 | City Name: constantine
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=constantine,dz&units=imperial
# Processing Record #199 | City ID: 6957998 | City Name: xiongzhou
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=xiongzhou,cn&units=imperial
# Processing Record #200 | City ID: 2122090 | City Name: pevek
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=pevek,ru&units=imperial
# Processing Record #201 | City ID: 2964782 | City Name: dingle
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=dingle,ie&units=imperial
# Processing Record #202 | City ID: 602913 | City Name: skelleftea
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=skelleftea,se&units=imperial
# Processing Record #203 | City ID: 2120048 | City Name: ust-nera
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=ust-nera,ru&units=imperial
# Processing Record #204 | City ID: 6945992 | City Name: betsiamites
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=betsiamites,ca&units=imperial
# Processing Record #205 | City ID: 636947 | City Name: siilinjarvi
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=siilinjarvi,fi&units=imperial
# Processing Record #206 | City ID: 3520994 | City Name: puerto escondido
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=puerto escondido,mx&units=imperial
# Processing Record #207 | City ID: 5033918 | City Name: lake shore
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=lake shore,us&units=imperial
# Processing Record #208 | City ID: 5856516 | City Name: ahuimanu
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=ahuimanu,us&units=imperial
# Processing Record #209 | City ID: 3573197 | City Name: hamilton
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=hamilton,bm&units=imperial
# Processing Record #210 | City ID: 3860443 | City Name: comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=comodoro rivadavia,ar&units=imperial
# Processing Record #211 | City ID: 2194098 | City Name: ahipara
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=ahipara,nz&units=imperial
# Processing Record #212 | City ID: 505269 | City Name: primorsk
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=primorsk,ru&units=imperial
# Processing Record #213 | City ID: 2025099 | City Name: dauriya
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=dauriya,ru&units=imperial
# Processing Record #214 | City ID: 2123814 | City Name: leningradskiy
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=leningradskiy,ru&units=imperial
# Processing Record #215 | City ID: 2071860 | City Name: esperance
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=esperance,au&units=imperial
# Processing Record #216 | City ID: 87205 | City Name: darnah
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=darnah,ly&units=imperial
# Processing Record #217 | City ID: 1735634 | City Name: kuching
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=kuching,my&units=imperial
# Processing Record #218 | City ID: 2152659 | City Name: port macquarie
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=port macquarie,au&units=imperial
# Processing Record #219 | City ID: 1488774 | City Name: tyukhtet
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=tyukhtet,ru&units=imperial
# Processing Record #220 | City ID: 1635815 | City Name: maumere
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=maumere,id&units=imperial
# Processing Record #221 | City ID: 3514843 | City Name: vega de alatorre
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=vega de alatorre,mx&units=imperial
# Processing Record #222 | City ID: 107304 | City Name: buraydah
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=buraydah,sa&units=imperial
# Processing Record #223 | City ID: 1528998 | City Name: yumen
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=yumen,cn&units=imperial
# Processing Record #224 | City ID: 4634662 | City Name: kingsport
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=kingsport,us&units=imperial
# Processing Record #225 | City ID: 4898722 | City Name: oneida
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=oneida,us&units=imperial
# Processing Record #226 | City ID: 3902377 | City Name: trinidad
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=trinidad,bo&units=imperial
# Processing Record #227 | City ID: 1857766 | City Name: miyazu
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=miyazu,jp&units=imperial
# Processing Record #228 | City ID: 670777 | City Name: pipirig
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=pipirig,ro&units=imperial
# Processing Record #229 | City ID: 2017155 | City Name: saskylakh
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=saskylakh,ru&units=imperial
# Processing Record #230 | City ID: 1154689 | City Name: ko samui
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=ko samui,th&units=imperial
# Processing Record #231 | City ID: 5563397 | City Name: eureka
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=eureka,us&units=imperial
# Processing Record #232 | City ID: 352733 | City Name: marsa matruh
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=marsa matruh,eg&units=imperial
# Processing Record #233 | City ID: 4490053 | City Name: piney green
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=piney green,us&units=imperial
# Processing Record #234 | City ID: 2035601 | City Name: nenjiang
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=nenjiang,cn&units=imperial
# Processing Record #235 | City ID: 5321473 | City Name: winslow
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=winslow,us&units=imperial
# Processing Record #236 | City ID: 5871146 | City Name: palmer
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=palmer,us&units=imperial
# Processing Record #237 | City ID: 153955 | City Name: micheweni
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=micheweni,tz&units=imperial
# Processing Record #238 | City ID: 4034551 | City Name: faanui
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=faanui,pf&units=imperial
# Processing Record #239 | City ID: 5354943 | City Name: half moon bay
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=half moon bay,us&units=imperial
# Processing Record #240 | City ID: 2977921 | City Name: saint-nazaire
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=saint-nazaire,fr&units=imperial
# Processing Record #241 | City ID: 3870243 | City Name: taltal
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=taltal,cl&units=imperial
# Processing Record #242 | City ID: 5517061 | City Name: big spring
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=big spring,us&units=imperial
# Processing Record #243 | City ID: 1637001 | City Name: luwuk
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=luwuk,id&units=imperial
# Processing Record #244 | City ID: 3848950 | City Name: la rioja
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=la rioja,ar&units=imperial
# Processing Record #245 | City ID: 5380420 | City Name: pacifica
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=pacifica,us&units=imperial
# Processing Record #246 | City ID: 2156643 | City Name: mount gambier
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=mount gambier,au&units=imperial
# Processing Record #247 | City ID: 1798760 | City Name: pingliang
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=pingliang,cn&units=imperial
# Processing Record #248 | City ID: 3664980 | City Name: boa vista
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=boa vista,br&units=imperial
# Processing Record #249 | City ID: 2636638 | City Name: stromness
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=stromness,gb&units=imperial
# Processing Record #250 | City ID: 2074865 | City Name: carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=carnarvon,au&units=imperial
# Processing Record #251 | City ID: 2173911 | City Name: broken hill
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=broken hill,au&units=imperial
# Processing Record #252 | City ID: 3381538 | City Name: grand-santi
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=grand-santi,gf&units=imperial
# Processing Record #253 | City ID: 1310120 | City Name: mawlaik
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=mawlaik,mm&units=imperial
# Processing Record #254 | City ID: 1521762 | City Name: kurchum
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=kurchum,kz&units=imperial
# Processing Record #255 | City ID: 3067553 | City Name: prestice
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=prestice,cz&units=imperial
# Processing Record #256 | City ID: 3580733 | City Name: bodden town
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=bodden town,ky&units=imperial
# Processing Record #257 | City ID: 371745 | City Name: kutum
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=kutum,sd&units=imperial
# Processing Record #258 | City ID: 1258290 | City Name: rayadrug
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=rayadrug,in&units=imperial
# Processing Record #259 | City ID: 617659 | City Name: ocnita
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=ocnita,md&units=imperial
# Processing Record #260 | City ID: 2012530 | City Name: zhigansk
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=zhigansk,ru&units=imperial
# Processing Record #261 | City ID: 4031637 | City Name: lavrentiya
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=lavrentiya,ru&units=imperial
# Processing Record #262 | City ID: 1510377 | City Name: belyy yar
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=belyy yar,ru&units=imperial
# Processing Record #263 | City ID: 2395182 | City Name: bembereke
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=bembereke,bj&units=imperial
# Processing Record #264 | City ID: 2126710 | City Name: beringovskiy
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=beringovskiy,ru&units=imperial
# Processing Record #265 | City ID: 1540711 | City Name: muravlenko
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=muravlenko,ru&units=imperial
# Processing Record #266 | City ID: 5978133 | City Name: hudson bay
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=hudson bay,ca&units=imperial
# Processing Record #267 | City ID: 1515029 | City Name: ulaangom
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=ulaangom,mn&units=imperial
# Processing Record #268 | City ID: 3919720 | City Name: colquechaca
# ...
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=luganville,vu&units=imperial
# Processing Record #413 | City ID: 485206 | City Name: syntul
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=syntul,ru&units=imperial
# Processing Record #414 | City ID: 2644597 | City Name: letchworth
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=letchworth,gb&units=imperial
# Processing Record #415 | City ID: 503977 | City Name: marfino
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=marfino,ru&units=imperial
# Processing Record #416 | City ID: 2185128 | City Name: paengaroa
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=paengaroa,nz&units=imperial
# Processing Record #417 | City ID: 1734052 | City Name: sandakan
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=sandakan,my&units=imperial
# Processing Record #418 | City ID: 1485284 | City Name: zelenogorskiy
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=zelenogorskiy,ru&units=imperial
# Processing Record #419 | City ID: 2629833 | City Name: husavik
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=husavik,is&units=imperial
# Processing Record #420 | City ID: 1519385 | City Name: sergeyevka
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=sergeyevka,kz&units=imperial
# Processing Record #421 | City ID: 3985168 | City Name: san patricio
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=san patricio,mx&units=imperial
# Processing Record #422 | City ID: 2177233 | City Name: bairnsdale
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=bairnsdale,au&units=imperial
# Processing Record #423 | City ID: 1622318 | City Name: waingapu
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=waingapu,id&units=imperial
# Processing Record #424 | City ID: 2136825 | City Name: isangel
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=isangel,vu&units=imperial
# Processing Record #425 | City ID: 3448903 | City Name: sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=sao joao da barra,br&units=imperial
# Processing Record #426 | City ID: 2152668 | City Name: portland
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=portland,au&units=imperial
# Processing Record #427 | City ID: 3894426 | City Name: coihaique
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=coihaique,cl&units=imperial
# Processing Record #428 | City ID: 2622854 | City Name: dybbol
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=dybbol,dk&units=imperial
# Processing Record #429 | City ID: 978895 | City Name: margate
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=margate,za&units=imperial
# Processing Record #430 | City ID: 3698359 | City Name: chicama
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=chicama,pe&units=imperial
# Processing Record #431 | City ID: 336454 | City Name: ginir
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=ginir,et&units=imperial
# Processing Record #432 | City ID: 1716788 | City Name: cortes
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=cortes,ph&units=imperial
# Processing Record #433 | City ID: 1067565 | City Name: beloha
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=beloha,mg&units=imperial
# Processing Record #434 | City ID: 1634614 | City Name: nabire
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=nabire,id&units=imperial
# Processing Record #435 | City ID: 1486321 | City Name: yar-sale
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=yar-sale,ru&units=imperial
# Processing Record #436 | City ID: 1685422 | City Name: sulangan
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=sulangan,ph&units=imperial
# Processing Record #437 | City ID: 2138285 | City Name: tadine
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=tadine,nc&units=imperial
# Processing Record #438 | City ID: 7626370 | City Name: bud
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=bud,no&units=imperial
# Processing Record #439 | City ID: 2122389 | City Name: ossora
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=ossora,ru&units=imperial
# Processing Record #440 | City ID: 702477 | City Name: lyubech
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=lyubech,ua&units=imperial
# Processing Record #441 | City ID: 608270 | City Name: shubarshi
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=shubarshi,kz&units=imperial
# Processing Record #442 | City ID: 1274315 | City Name: chhibramau
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=chhibramau,in&units=imperial
# Processing Record #443 | City ID: 3402000 | City Name: codo
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=codo,br&units=imperial
# Processing Record #444 | City ID: 1630662 | City Name: praya
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=praya,id&units=imperial
# Processing Record #445 | City ID: 2138607 | City Name: pouebo
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=pouebo,nc&units=imperial
# Processing Record #446 | City ID: 2144528 | City Name: warrnambool
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=warrnambool,au&units=imperial
# Processing Record #447 | City ID: 5301388 | City Name: lake havasu city
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=lake havasu city,us&units=imperial
# Processing Record #448 | City ID: 2160735 | City Name: lakes entrance
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=lakes entrance,au&units=imperial
# Processing Record #449 | City ID: 3374346 | City Name: ponta do sol
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=ponta do sol,cv&units=imperial
# Processing Record #450 | City ID: 3664539 | City Name: coari
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=coari,br&units=imperial
# Processing Record #451 | City ID: 3466980 | City Name: caravelas
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=caravelas,br&units=imperial
# Processing Record #452 | City ID: 3347353 | City Name: menongue
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=menongue,ao&units=imperial
# Processing Record #453 | City ID: 1791779 | City Name: wanning
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=wanning,cn&units=imperial
# Processing Record #454 | City ID: 779554 | City Name: honningsvag
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=honningsvag,no&units=imperial
# Processing Record #455 | City ID: 2610343 | City Name: vestmanna
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=vestmanna,fo&units=imperial
# Processing Record #456 | City ID: 2027044 | City Name: batagay
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=batagay,ru&units=imperial
# Processing Record #457 | City ID: 3406196 | City Name: barreirinhas
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=barreirinhas,br&units=imperial
# Processing Record #458 | City ID: 5069297 | City Name: grand island
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=grand island,us&units=imperial
# Processing Record #459 | City ID: 5983626 | City Name: invermere
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=invermere,ca&units=imperial
# Processing Record #460 | City ID: 986717 | City Name: kruisfontein
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=kruisfontein,za&units=imperial
# Processing Record #461 | City ID: 2016412 | City Name: smidovich
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=smidovich,ru&units=imperial
# Processing Record #462 | City ID: 3359638 | City Name: walvis bay
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=walvis bay,na&units=imperial
# Processing Record #463 | City ID: 2618795 | City Name: klaksvik
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=klaksvik,fo&units=imperial
# Processing Record #464 | City ID: 2178753 | City Name: kirakira
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=kirakira,sb&units=imperial
# Processing Record #465 | City ID: 3354876 | City Name: okakarara
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=okakarara,na&units=imperial
# Processing Record #466 | City ID: 477940 | City Name: ust-tsilma
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=ust-tsilma,ru&units=imperial
# Processing Record #467 | City ID: 6138501 | City Name: saint-augustin
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=saint-augustin,ca&units=imperial
# Processing Record #468 | City ID: 5859699 | City Name: college
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=college,us&units=imperial
# Processing Record #469 | City ID: 2090021 | City Name: namatanai
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=namatanai,pg&units=imperial
# Processing Record #470 | City ID: 3897347 | City Name: calama
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=calama,cl&units=imperial
# Processing Record #471 | City ID: 2036892 | City Name: hohhot
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=hohhot,cn&units=imperial
# Processing Record #472 | City ID: 103630 | City Name: najran
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=najran,sa&units=imperial
# Processing Record #473 | City ID: 119374 | City Name: qeshm
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=qeshm,ir&units=imperial
# Processing Record #474 | City ID: 3451126 | City Name: bonfim
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=bonfim,br&units=imperial
# Processing Record #475 | City ID: 5887916 | City Name: athabasca
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=athabasca,ca&units=imperial
# Processing Record #476 | City ID: 211098 | City Name: lubao
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=lubao,cd&units=imperial
# Processing Record #477 | City ID: 162627 | City Name: yabrud
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=yabrud,sy&units=imperial
# Processing Record #478 | City ID: 1488903 | City Name: turukhansk
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=turukhansk,ru&units=imperial
# Processing Record #479 | City ID: 1809498 | City Name: guilin
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=guilin,cn&units=imperial
# Processing Record #480 | City ID: 359792 | City Name: aswan
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=aswan,eg&units=imperial
# Processing Record #481 | City ID: 217562 | City Name: butembo
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=butembo,cd&units=imperial
# Processing Record #482 | City ID: 1607017 | City Name: rayong
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=rayong,th&units=imperial
# Processing Record #483 | City ID: 3822702 | City Name: kantunilkin
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=kantunilkin,mx&units=imperial
# Processing Record #484 | City ID: 2188874 | City Name: russell
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=russell,nz&units=imperial
# Processing Record #485 | City ID: 3480908 | City Name: la asuncion
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=la asuncion,ve&units=imperial
# Processing Record #486 | City ID: 2274895 | City Name: monrovia
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=monrovia,lr&units=imperial
# Processing Record #487 | City ID: 1277936 | City Name: bagalkot
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=bagalkot,in&units=imperial
# Processing Record #488 | City ID: 1529376 | City Name: korla
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=korla,cn&units=imperial
# Processing Record #489 | City ID: 2108857 | City Name: gizo
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=gizo,sb&units=imperial
# Processing Record #490 | City ID: 561515 | City Name: giaginskaya
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=giaginskaya,ru&units=imperial
# Processing Record #491 | City ID: 2514651 | City Name: los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=los llanos de aridane,es&units=imperial
# Processing Record #492 | City ID: 546060 | City Name: koltubanovskiy
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=koltubanovskiy,ru&units=imperial
# Processing Record #493 | City ID: 1011632 | City Name: de aar
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=de aar,za&units=imperial
# Processing Record #494 | City ID: 3668605 | City Name: santa marta
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=santa marta,co&units=imperial
# Processing Record #495 | City ID: 2685750 | City Name: ostersund
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=ostersund,se&units=imperial
# Processing Record #496 | City ID: 2025630 | City Name: chara
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=chara,ru&units=imperial
# Processing Record #497 | City ID: 786142 | City Name: sajkas
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=sajkas,rs&units=imperial
# Processing Record #498 | City ID: 4407010 | City Name: saint joseph
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=saint joseph,us&units=imperial
# Processing Record #499 | City ID: 3356832 | City Name: henties bay
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=henties bay,na&units=imperial
# Processing Record #500 | City ID: 6111862 | City Name: port hardy
# http://api.openweathermap.org/data/2.5/weather?appid=84fe59f3ffa1bf7920c39149bf3dde70&q=port hardy,ca&units=imperial

# %%
# Output to csv
weather_data_df.to_csv("weather_data.csv", encoding="utf-8", index=False)

# %%
# Display the count for each column in the Data Frame
weather_data_df.count()
# Out:
# City           500
# Cloudiness     500
# Country        500
# Date           500
# Humidity       500
# Lat            500
# Lng            500
# Temperature    500
# Wind Speed     500
# dtype: int64

# %%
# Display the Weather Data Frame
weather_data_df.head()
# Out:
#            City Cloudiness Country        Date Humidity    Lat     Lng  \
# 0     Zandvoort          0      NL  1519941300       57  52.37    4.53
# 0  Saint George         75      BM  1519937700       64  32.38  -64.68
# 0  Longyearbyen         20      SJ  1519941000       61  78.22   15.64
# 0       Dunedin         92      NZ  1519942570       94 -45.87  170.50
# 0         Tiksi         64      RU  1519942449       58  71.64  128.87
#
#    Temperature  Wind Speed
# 0        24.84       23.04
# 0        69.80       13.87
# 0        12.20       13.87
# 0        61.48        3.76
# 0       -20.29        3.76

# %%
### Create the necessary graphs from the data frame
### AND SAVE each image as .png files

## Temperature (F) vs. Latitude
plt.title("City Latitude vs. Temperature (3/1/2018)")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")

plt.xlim(min(weather_data_df["Lat"])-20, max(weather_data_df["Lat"]) + 20)
plt.ylim(min(weather_data_df["Temperature"])-50, max(weather_data_df["Temperature"]) + 50)


plt.scatter(weather_data_df["Lat"], weather_data_df["Temperature"], s =20, edgecolor = "black", c = "blue")
sns.set()
plt.savefig("City-Latitude-vs-Temperature.png")
plt.show()

# %%
## Humidity (%) vs. Latitude
plt.title("City Latitude vs. Humidity (3/1/2018)")
plt.xlabel("Latitude")
plt.ylabel("Humdity (%)")

plt.xlim(min(weather_data_df["Lat"])-20, max(weather_data_df["Lat"]) + 20)
plt.ylim(min(weather_data_df["Humidity"])-20, max(weather_data_df["Humidity"]) + 20)


plt.scatter(weather_data_df["Lat"], weather_data_df["Humidity"], s =20, edgecolor = "black", c = "blue")
sns.set()
plt.savefig("City-Latitude-vs-Humidity.png")
plt.show()

# %%
## Cloudiness (%) vs. Latitude
plt.title("City Latitude vs. Cloudiness (3/1/2018)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

plt.xlim(min(weather_data_df["Lat"])-20, max(weather_data_df["Lat"]) + 20)
plt.ylim(min(weather_data_df["Cloudiness"])-20, max(weather_data_df["Cloudiness"]) + 20)


plt.scatter(weather_data_df["Lat"], weather_data_df["Cloudiness"], s =20, edgecolor = "black", c = "blue")
sns.set()
plt.savefig("City-Latitude-vs-Cloudiness.png")
plt.show()

# %%
## Wind Speed (mph) vs. Latitude
plt.title("City Latitude vs. Wind Speed (3/1/2018)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

plt.xlim(min(weather_data_df["Lat"])-20, max(weather_data_df["Lat"]) + 20)
plt.ylim(min(weather_data_df["Wind Speed"])-10, max(weather_data_df["Wind Speed"]) + 10)


plt.scatter(weather_data_df["Lat"], weather_data_df["Wind Speed"], s =20, edgecolor = "black", c = "blue")
sns.set()
plt.savefig("City-Latitude-vs-Wind-Speed.png")
plt.show()
